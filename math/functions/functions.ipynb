# %% [markdown]
# # Introduction to Functions | Representation | Types | Examples

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Types of algebraic functions

# %% [markdown]
# ### Linear Function

# %% [markdown]
# ### Cubic Function

# %% [markdown]
# ### Quadratic Function

# %% [markdown]
# ### Modulus Function

# %% [markdown]
# ### Polynomial Function

# %% [markdown]
# ### Rational Function

# %% [markdown]
# ### Radical Functions

# %% [markdown]
# ## Trigonometric Functions

# %% [markdown]
# ### Sine Function

# %% [markdown]
# ### Cosine Function

# %% [markdown]
# ### Tangent Functions
